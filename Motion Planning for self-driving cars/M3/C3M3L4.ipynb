# %% [markdown]
# # Lanete map
#
# - In the context of self-driving cars, a LANElet map is a apecialized type of map that represents the road network in terms of individuals lanes rather than just general roads. Lanelets break down roadways into smallet, more granular units, allowing autonomous vehicles to navigate precisely within individuals lanes, follow traffic rules and interact safely with other road users.
#
# ## Key components of a lanelet map
#
# 1. Lanelets
# 2. Boundaries
# 3. Connections
# 4. Regulatory Elements
# 5. Traffic rules and priority handling
#
# ## Why lanelet maps are essential for self-driving cars
#
# 1. Precision
# 2. Decision making
# 3. Traffic rule compliance
# 4. Adaptability
#
# # Lanelet element
#
# - Defines the following:
# 1. Left and right boundaries
# 2. Regulation: Elements, attributes
# 3. Connectivity to other lanelets
#
# - A new lanelet is created whn a new regulatory element is encountered or ends
#
# # Lanelet boundaries
#
# - Defines the edges of a driving lane
# - A list of pointers points creating a polygonal line: X, y, and z coordinates
# - Different operation can be performed on boundaries: Heading, curvature, center line
#
# # Lanelet regulations:
#
# - Elements - a list of points creating a line identifying stop location
# 1. Stop line
# 2. traffic lights line
# 3. Pedestrian crossings
# - Attributes - a set of regulation attributes assigned to a lanelet
# 1. Speed limit
# 2. Crossing another lanelet
#
#
# # Intersections:
#
# - Intersection Element: Pointer to all lanelets which are part of an intersection
# - Helps with behaviour assignments
#
# # operations done on lanelets
#
# - Path planning through complex road networks
# - Localize dynamic objects
# - Interactions with other dynamic objects
#
# # Creations of lanelets
#
# - 3 methods to create the lanelet:
# 1. Offline creation
# 2. Online creation
# 3. Offline creation with online update
